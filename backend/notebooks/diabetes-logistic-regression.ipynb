# %% [markdown]
# # <font color="orange"> Logistic Regression Project: Diabetes Prediction </font>

# %%
# import required libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt 
import seaborn as sns
import plotly.express as px
import plotly.graph_objects as go
import plotly.io as pio
import itertools

# for solve problem of show plotly plots
from plotly.offline import init_notebook_mode
init_notebook_mode(connected=True)

from warnings import filterwarnings
filterwarnings('ignore')
plt.style.use('_mpl-gallery')
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         </script>
#         <script type="module">import "https://cdn.plot.ly/plotly-3.1.1.min"</script>

# %%
from sklearn.model_selection import train_test_split , GridSearchCV, KFold, cross_val_score, RepeatedStratifiedKFold
from sklearn.preprocessing import MinMaxScaler , StandardScaler
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay, classification_report
from sklearn import metrics

# %%
# import diabetes dataset
data = pd.read_csv("../data/diabetes.csv")
data
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 1              1       85             66             29        0  26.6
# 2              8      183             64              0        0  23.3
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  outcome
# 0                       0.627   50        1
# 1                       0.351   31        0
# 2                       0.672   32        1
# 3                       0.167   21        0
# 4                       2.288   33        1
# ..                        ...  ...      ...
# 763                     0.171   63        0
# 764                     0.340   27        0
# 765                     0.245   30        0
# 766                     0.349   47        1
# 767                     0.315   23        0
#
# [768 rows x 9 columns]

# %% [markdown]
# # <font color='orange'> 1. Dataset Overview </font>

# %%
df = pd.DataFrame(data)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 768 entries, 0 to 767
# Data columns (total 9 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Pregnancies               768 non-null    int64
#  1   Glucose                   768 non-null    int64
#  2   BloodPressure             768 non-null    int64
#  3   SkinThickness             768 non-null    int64
#  4   Insulin                   768 non-null    int64
#  5   BMI                       768 non-null    float64
#  6   DiabetesPedigreeFunction  768 non-null    float64
#  7   Age                       768 non-null    int64
#  8   outcome                   768 non-null    int64
# dtypes: float64(2), int64(7)
# memory usage: 54.1 KB

# %% [markdown]
# # <font color='orange'> 2. Cleaning and Preparing Data </font>

# %%
df.isnull().sum()
# df.isna().sum()
# Out:
# Pregnancies                 0
# Glucose                     0
# BloodPressure               0
# SkinThickness               0
# Insulin                     0
# BMI                         0
# DiabetesPedigreeFunction    0
# Age                         0
# outcome                     0
# dtype: int64

# %% [markdown]
# We have 9 columns, none of which seem to have missing values

# %%
df.describe().T
# Out:
#                           count        mean         std     min       25%  \
# Pregnancies               768.0    3.845052    3.369578   0.000   1.00000
# Glucose                   768.0  120.894531   31.972618   0.000  99.00000
# BloodPressure             768.0   69.105469   19.355807   0.000  62.00000
# SkinThickness             768.0   20.536458   15.952218   0.000   0.00000
# Insulin                   768.0   79.799479  115.244002   0.000   0.00000
# BMI                       768.0   31.992578    7.884160   0.000  27.30000
# DiabetesPedigreeFunction  768.0    0.471876    0.331329   0.078   0.24375
# Age                       768.0   33.240885   11.760232  21.000  24.00000
# outcome                   768.0    0.348958    0.476951   0.000   0.00000
#
#                                50%        75%     max
# Pregnancies                 3.0000    6.00000   17.00
# Glucose                   117.0000  140.25000  199.00
# BloodPressure              72.0000   80.00000  122.00
# SkinThickness              23.0000   32.00000   99.00
# Insulin                    30.5000  127.25000  846.00
# BMI                        32.0000   36.60000   67.10
# DiabetesPedigreeFunction    0.3725    0.62625    2.42
# Age                        29.0000   41.00000   81.00
# outcome                     0.0000    1.00000    1.00

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %% [markdown]
# Ok There is no duplicate data

# %%
# Now draw plots and check the noisy data:
# first we check the data distribution:
# %matplotlib inline
fig, ax = plt.subplots(3,3,figsize=(15,9))
for i, col in enumerate(df):
    sns.histplot(df[col], kde=True, ax=ax[i//3, i%3])
    # plt.title(f"{col} ditribution", fontsize=14, fontweight='bold', c='r')
plt.show()

# %%
df1 = df.copy()
zero_col = ['Glucose','Insulin','SkinThickness','BloodPressure','BMI']
df1[zero_col] = df1[zero_col].replace(0, np.nan)

# %%
df1.isna().sum()
# Out:
# Pregnancies                   0
# Glucose                       5
# BloodPressure                35
# SkinThickness               227
# Insulin                     374
# BMI                          11
# DiabetesPedigreeFunction      0
# Age                           0
# outcome                       0
# dtype: int64

# %%
# %matplotlib inline
sns.heatmap(data.corr(), annot=True, cmap='Reds')
plt.show()

# %% [markdown]
# - I don't have expertise or science in medicine, but I think that glucose, insulin, skin thickness, blood pressure, and BMI cannot have a zero value, and since I don't have access to the owner of the data to research this data, so I have to fill or drop these data
# - The features do not have much correlation with each other and therefore they cannot be filled according to each other. Also, since the number of false zero data is high, removing them is not a good solution so I fill them according to distribution data
# - Mean is most useful when the original data is not skewed, while the median is more robust, not sensitive to outliers, and thus used when data is skewed.
# - As can be seen in the data distribution charts, insulin, glucose and skin thickness are deviated to the right and left, so we fill them with Madin. On the other hand, BMI and blood pressure have a normal distribution and we use the average to fill them

# %%
for col in ['Glucose','Insulin','SkinThickness']:
    median_col = np.median(df1[df1[col].notna()][col])
    df1[col] = df1[col].fillna(median_col)
for col in ['BMI','BloodPressure']:
    mean_col = np.mean(df1[df1[col].notna()][col])
    df1[col] = df1[col].fillna(mean_col)

# %%
df1.isna().sum()
# Out:
# Pregnancies                 0
# Glucose                     0
# BloodPressure               0
# SkinThickness               0
# Insulin                     0
# BMI                         0
# DiabetesPedigreeFunction    0
# Age                         0
# outcome                     0
# dtype: int64

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 768 entries, 0 to 767
# Data columns (total 9 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Pregnancies               768 non-null    int64
#  1   Glucose                   768 non-null    float64
#  2   BloodPressure             768 non-null    float64
#  3   SkinThickness             768 non-null    float64
#  4   Insulin                   768 non-null    float64
#  5   BMI                       768 non-null    float64
#  6   DiabetesPedigreeFunction  768 non-null    float64
#  7   Age                       768 non-null    int64
#  8   outcome                   768 non-null    int64
# dtypes: float64(6), int64(3)
# memory usage: 54.1 KB

# %% [markdown]
# # <font color="orange"> 3.Exploratory Data Analysis (EDA) </font>

# %% [markdown]
# ### <font color="orange"> 3.1.Univariate Analysis: </font>

# %%
df1.describe().T
# Out:
#                           count        mean        std     min        25%  \
# Pregnancies               768.0    3.845052   3.369578   0.000    1.00000
# Glucose                   768.0  121.656250  30.438286  44.000   99.75000
# BloodPressure             768.0   72.405184  12.096346  24.000   64.00000
# SkinThickness             768.0   29.108073   8.791221   7.000   25.00000
# Insulin                   768.0  140.671875  86.383060  14.000  121.50000
# BMI                       768.0   32.457464   6.875151  18.200   27.50000
# DiabetesPedigreeFunction  768.0    0.471876   0.331329   0.078    0.24375
# Age                       768.0   33.240885  11.760232  21.000   24.00000
# outcome                   768.0    0.348958   0.476951   0.000    0.00000
#
#                                  50%        75%     max
# Pregnancies                 3.000000    6.00000   17.00
# Glucose                   117.000000  140.25000  199.00
# BloodPressure              72.202592   80.00000  122.00
# SkinThickness              29.000000   32.00000   99.00
# Insulin                   125.000000  127.25000  846.00
# BMI                        32.400000   36.60000   67.10
# DiabetesPedigreeFunction    0.372500    0.62625    2.42
# Age                        29.000000   41.00000   81.00
# outcome                     0.000000    1.00000    1.00

# %% [markdown]
# - According to above table, Most people in this dataset do not have diabetes.

# %% [markdown]
# #### <font color="orange"> 3.2.Numeric - Numeric Bivariate Analysis: </font>

# %%
# %matplotlib inline
sns.pairplot(data=df1, diag_kind='kde', hue='outcome')
plt.show()

# %%
fig = go.Figure()
my_cols = ['Pregnancies','Glucose','BloodPressure','SkinThickness',
           'Insulin','BMI','DiabetesPedigreeFunction','Age']
for col in my_cols:
    fig.add_trace(go.Box(y=df1[col], name=f'{col}'))
fig.show()
# Out:
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.1.1.min.js" integrity="sha256-HUEFyfiTnZJxCxur99FjbKYTvKSzwDaD3/x5TqHpFu4=" crossorigin="anonymous"></script>                <div id="f57983ce-15ef-4489-b6b3-ae0cd40f64a7" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("f57983ce-15ef-4489-b6b3-ae0cd40f64a7")) {                    Plotly.newPlot(                        "f57983ce-15ef-4489-b6b3-ae0cd40f64a7",                        [{"name":"Pregnancies","y":{"dtype":"i1","bdata":"..."},"type":"box"},{"name":"Glucose","y":{"dtype":"f8","bdata":"..."},"type":"box"},{"name":"BloodPressure","y":{"dtype":"f8","bdata":"..."},"type":"box"},{"name":"SkinThickness","y":{"dtype":"f8","bdata":"\...\...\...\..."},"type":"box"},{"name":"Insulin","y":{"dtype":"f8","bdata":"..."},"type":"box"},{"name":"BMI","y":{"dtype":"f8","bdata":"\u002fQDMzMzMzs0NAMzMzMzMzN0AzMzMzMzM2QM3MzMzMDEFAAAAAAAAAQkCamZmZmZk\...\u002fQAAAAAAAAEFAAAAAAACAPkAzMzMzMzM\...\...\\u002fNCQDMzMzMz80FAMzMzMzMzQEBmZmZmZmY+QAAAAAAAADtAAAAAAAAAOkCamZmZmVlDQM3MzMzMzEZAzczMzMzMNEDNzMzMzAxCQDMzMzMzc0JAzczMzMxMQkBmZmZmZqZFQAAAAAAAQERAZmZmZmbmNUAAAAAAAMBBQAAAAAAAADxAMzMzMzOzPkDNzMzMzExCQJqZmZmZmTdAZmZmZmYmQECamZmZmZk\\...\...\...\...\u002fNBQJqZmZmZmTtAAAAAAACAQUAAAAAAAEBDQGZmZmZmZjxAZmZmZmbmQ0CEA2wrjjpAQDMzMzMzM0FAZmZmZmZmQEAAAAAAAABDQDMzMzMzMz9AmpmZmZmZPUCamZmZmZlEQGZmZmZmZjpAAAAAAACAPUAzMzMzM\..."},"type":"box"},{"name":"DiabetesPedigreeFunction","y":{"dtype":"f8","bdata":"qvHSTWIQ5D8QWDm0yHbWPxsv3SQGgeU\u002fx0s3iUFgxT\u002fn+6nx0k0CQO58PzVeusk\u002fWDm0yHa+zz\u002f0\u002fdR46SbBP9NNYhBYOcQ\u002fGQRWDi2yzT+mm8QgsHLIP8l2vp8aL+E\u002fdZMYBFYO9z9GtvP91HjZP2IQWDm0yOI\u002fYOXQItv53j9vEoPAyqHhP6jGSzeJQdA\u002fBoGVQ4tsxz8hsHJoke3gP7pJDAIrh+Y\u002fokW28\u002f3U2D93vp8aL93cP6JFtvP91NA\u002fqMZLN4lB0D89CtejcD3KP6abxCCwctA\u002fXrpJDAIr3z9cj8L1KFzPP8UgsHJokdU\u002fRrbz\u002fdR44T8IrBxaZDvrP0oMAiuHFtE\u002fqvHSTWIQyD\u002f8qfHSTWLgP7bz\u002fdR46e4\u002f4XoUrkfh2j9I4XoUrkflP39qvHSTGOA\u002fPQrXo3A99j\u002fy0k1iEFjRPxKDwMqhReY\u002fFK5H4XoUzj\u002ffT42XbhLnPzeJQWDl0NI\u002ffT81XrpJ\u002fj8\u002fNV66SQziP42XbhKDwOI\u002farx0kxgE1j+F61G4HoXTPwaBlUOLbN8\u002fokW28\u002f3U4D8X2c73U+PVPxfZzvdT490\u002fYOXQItv55j9YObTIdr7PP6jGSzeJQdA\u002fYhBYObTI7j\u002fl0CLb+X78P76fGi\u002fdJMY\u002f2\u002fl+arx00z9I4XoUrkfRP2IQWDm0yOI\u002fke18PzVe5j9QjZduEoPQP5ZDi2zn+8k\u002fXI\u002fC9Shc6z8K16NwPQrrP8dLN4lBYNU\u002f\u002ftR46SYxyD9YObTIdr7rP+f7qfHSTdo\u002fDi2yne+n4j\u002fFILByaJHNP\u002fLS ...

# %% [markdown]
# # <font color='orange'> 4.Model </font>

# %%
df1
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6    148.0           72.0           35.0    125.0  33.6
# 1              1     85.0           66.0           29.0    125.0  26.6
# 2              8    183.0           64.0           29.0    125.0  23.3
# 3              1     89.0           66.0           23.0     94.0  28.1
# 4              0    137.0           40.0           35.0    168.0  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10    101.0           76.0           48.0    180.0  32.9
# 764            2    122.0           70.0           27.0    125.0  36.8
# 765            5    121.0           72.0           23.0    112.0  26.2
# 766            1    126.0           60.0           29.0    125.0  30.1
# 767            1     93.0           70.0           31.0    125.0  30.4
#
#      DiabetesPedigreeFunction  Age  outcome
# 0                       0.627   50        1
# 1                       0.351   31        0
# 2                       0.672   32        1
# 3                       0.167   21        0
# 4                       2.288   33        1
# ..                        ...  ...      ...
# 763                     0.171   63        0
# 764                     0.340   27        0
# 765                     0.245   30        0
# 766                     0.349   47        1
# 767                     0.315   23        0
#
# [768 rows x 9 columns]

# %%
# define x and y for modeling
x = df1.drop('outcome', axis=1)
y = df1.outcome

# %%
scaler = StandardScaler()
x_norm = scaler.fit_transform(x)
x_norm
# Out:
# array([[ 0.63994726,  0.86604475, -0.03351824, ...,  0.16629174,
#          0.46849198,  1.4259954 ],
#        [-0.84488505, -1.20506583, -0.52985903, ..., -0.85253118,
#         -0.36506078, -0.19067191],
#        [ 1.23388019,  2.01666174, -0.69530596, ..., -1.33283341,
#          0.60439732, -0.10558415],
#        ...,
#        [ 0.3429808 , -0.02157407, -0.03351824, ..., -0.91074963,
#         -0.68519336, -0.27575966],
#        [-0.84488505,  0.14279979, -1.02619983, ..., -0.34311972,
#         -0.37110101,  1.17073215],
#        [-0.84488505, -0.94206766, -0.19896517, ..., -0.29945588,
#         -0.47378505, -0.87137393]], shape=(768, 8))

# %%
# convert x_train_st to DataFrame
x = pd.DataFrame(x_norm, index=x.index, columns=x.columns)
x
# Out:
#      Pregnancies   Glucose  BloodPressure  SkinThickness   Insulin       BMI  \
# 0       0.639947  0.866045      -0.033518       0.670643 -0.181541  0.166292
# 1      -0.844885 -1.205066      -0.529859      -0.012301 -0.181541 -0.852531
# 2       1.233880  2.016662      -0.695306      -0.012301 -0.181541 -1.332833
# 3      -0.844885 -1.073567      -0.529859      -0.695245 -0.540642 -0.634212
# 4      -1.141852  0.504422      -2.680669       0.670643  0.316566  1.548980
# ..           ...       ...            ...            ...       ...       ...
# 763     1.827813 -0.679069       0.297376       2.150354  0.455573  0.064409
# 764    -0.547919  0.011301      -0.198965      -0.239949 -0.181541  0.632039
# 765     0.342981 -0.021574      -0.033518      -0.695245 -0.332132 -0.910750
# 766    -0.844885  0.142800      -1.026200      -0.012301 -0.181541 -0.343120
# 767    -0.844885 -0.942068      -0.198965       0.215347 -0.181541 -0.299456
#
#      DiabetesPedigreeFunction       Age
# 0                    0.468492  1.425995
# 1                   -0.365061 -0.190672
# 2                    0.604397 -0.105584
# 3                   -0.920763 -1.041549
# 4                    5.484909 -0.020496
# ..                        ...       ...
# 763                 -0.908682  2.532136
# 764                 -0.398282 -0.531023
# 765                 -0.685193 -0.275760
# 766                 -0.371101  1.170732
# 767                 -0.473785 -0.871374
#
# [768 rows x 8 columns]

# %%
# split data to train and test
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=0)

# %%
FPR1 = []
TPR1 = []
FPR0 = []
TPR0 = []
ACC = []
Recall = []
Precision = []
F1 = []

def plot_confusion_matrix2(cm, classes,
                          title='Confusion matrix',
                          cmap=plt.cm.Blues):
    """
    This function plots the confusion matrix.
        cm(array): confusion matrix
        classes(dictionary): classes in our target
    """
    plt.figure(figsize=(10,7))
    plt.grid(False)
    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title)
    plt.colorbar()
    tick_marks = np.arange(len(classes))
    plt.xticks(tick_marks, classes, rotation=45)
    plt.yticks(tick_marks, classes)

    fmt ='d'
    thresh = cm.max() / 2.
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(j, i, format(cm[i, j], fmt),
                 horizontalalignment="center",
                 color="white" if cm[i, j] > thresh else "black")

    
    plt.ylabel('Actual')
    plt.xlabel('Predicted')
    plt.tight_layout()
    plt.show()

# --------------------------------------------------------------------------------------

def Perform_cross_val(model, k, x, y, scoring):
    """
    perform cross validation
        model: logistic model
        k(scaler): the value for n_splits in KFold()
        x(DataFrame or array):  x_train
        y(DataFrame or array): y_train
        scoring(string): an approach for evaluation in cross validation
    """

    kf = KFold(n_splits=k)
    cv_results = cross_val_score(model, x, y, cv=kf, scoring=scoring)
    cv_mean = np.mean(cv_results)
    print('-'*20, f"CV for k={k}, scoring={scoring}", '-'*20)
    print(f"CV mean: {cv_mean}")
    print(f"CV results: {cv_results}\n")

# --------------------------------------------------------------------------------------

def find_fold_index(k, x):
    """
    Find fold index in kfold
        k(scaler): the value used for n_splits in KFold()
        x(DataFrame or array): x_train
    """

    my_fold_index = []
    j=1
    for _ , test in KFold(k).split(x):

        my_fold_index = []
        for i in test:
            my_fold_index.append(i)
        print(f"fold {j}: [{my_fold_index[0]},{my_fold_index[-1]}]")
        print(20*'-')
        j += 1

# --------------------------------------------------------------------------------------

def features_importance(model, x_test):
    """
    print feature weights and show imporance of each feature
        model: logistic regression
        x_test(Dataframe)
    """
    print('-'*20 , 'Feature', '-'*20)
    coeff = list(model.coef_[0])
    labels = list(x_test.columns)
    features = pd.DataFrame()
    features['Features'] = labels + ['Intercept']
    features['Importance'] = coeff + [model.intercept_[0]]
    features.sort_values(by=['Importance'], ascending=True, inplace=True)
    features['Positive'] = features['Importance'] > 0
    features.set_index('Features', inplace=True)
    features.Importance.plot(kind='barh', figsize=(5,3), 
                             color=features.Positive.map({True:'green', False:'orange'}))
    plt.xlabel('Importance')
    plt.show()
    return features

# --------------------------------------------------------------------------------------

def plot_results(FPR0, TPR0, FPR1, TPR1, ACC, Recall, Precision, F1):
    """
    draw ROC curve and plot of Recall, precision, f1 score etc.
        FPR0(list): list of False Positive Rate for class 0
        TPR0(list): list of True Positive Rate for class 0
        FPR1(list): list of Flase Positive Rate for class 1
        TPR1(list): list of True Positive Rate for class 1
        ACC(list): list of accuracy of models
        Recall(list): list of recall score of models
        Precision(list): list of Precision score of models
        F1(list): list of F1 score of models 
    """
    fig, ax = plt.subplots(1,3,figsize=(15,4))
    # plot model evaluation
    ax[0].set_title('Model Evaluation Results', fontsize=14, fontweight='bold')
    sns.lineplot(data=pd.DataFrame({'accoracy': ACC, 'Recall': Recall,
                                    'Precision': Precision, 'F1 score': F1}), 
                                    markers=True, ax=ax[0])
    ax[0].set_xlabel('M')
    ax[0].set_ylabel('Evaluation')
    ax[0].legend(loc='upper center', bbox_to_anchor=(0.5, -0.12),
          fancybox=True, shadow=True)

    # plot ROC curve for class 1
    i=1
    ax[1].set_title('ROC Curve of Class 1', fontsize=14, fontweight='bold')
    for fpr , tpr in zip(FPR1, TPR1):
        ax[1].plot(fpr, tpr, label=f"ROC curve of model{i} (AUC = {round(metrics.auc(fpr, tpr),3)})")
        i += 1
        ax[1].set_xlabel('FPR')
        ax[1].set_ylabel('TPR')
    ax[1].legend(loc='upper center', bbox_to_anchor=(0.5, -0.12),
          fancybox=True, shadow=True)
        
    # plot ROC curve for class zero
    i=1
    ax[2].set_title('ROC Curve of Class 0', fontsize=14, fontweight='bold')
    for fpr , tpr in zip(FPR0, TPR0):
        ax[2].plot(fpr, tpr, '--', label=f"ROC curve of model{i} (AUC = {round(metrics.auc(fpr, tpr),3)})")
        i += 1
        ax[2].set_xlabel('FPR')
        ax[2].set_ylabel('TPR')
    ax[2].legend(loc='upper center', bbox_to_anchor=(0.5, -0.12),
        fancybox=True, shadow=True)
    
    plt.show()

# --------------------------------------------------------------------------------------

def modeling(x, y, test_size, classes, parameters, is_add=1 ):

    # split data to train and test
    x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=test_size, random_state=0)

    # define model and fit model
    logreg = LogisticRegression(solver=parameters['solver'], penalty=parameters['penalty'],
                                C=parameters['C'], n_jobs=-1)
    logreg.fit(x_train, y_train)

    # prediction and results
    y_pred = logreg.predict(x_test)
    y_pred_proba = logreg.predict_proba(x_test)
    cm = confusion_matrix(y_test, y_pred, labels=[1,0])
    fpr1, tpr1, _ = metrics.roc_curve(y_test, y_pred_proba[:,1])
    fpr0, tpr0, _ = metrics.roc_curve(y_test, y_pred_proba[:,0])
    acc = metrics.accuracy_score(y_test, y_pred)
    rec = metrics.recall_score(y_test, y_pred)
    pre = metrics.precision_score(y_test, y_pred)
    f1 = metrics.f1_score(y_test, y_pred)

    # append results
    if is_add == 1:
        FPR0.append(fpr0)
        TPR0.append(tpr0)
        FPR1.append(fpr1)
        TPR1.append(tpr1)
        ACC.append(acc)
        Recall.append(rec)
        Precision.append(pre)
        F1.append(f1)

    plot_results(FPR0, TPR0, FPR1, TPR1, ACC, Recall, Precision, F1)

    # Evaluation model
    print('-'*20 , 'Confusion Matrix', '-'*20)
    print(cm)
    plot_confusion_matrix2(cm, classes,
                          title='Confusion matrix',
                          cmap=plt.cm.Blues)
    # or use plot_confusion_matrix from sklearn.metrics
    print('-'*20 , 'Classification Report', '-'*20)
    print(classification_report(y_test, y_pred, target_names=classes), '\n')
    print(f"Jaccard Score: {metrics.jaccard_score(y_test, y_pred)}", '\n')

    # print other result about weight and predicted data
    return logreg, acc, features_importance(logreg, x_test)

# %%
# define model
logreg = LogisticRegression(solver='liblinear')

# check cross validation
cross5_acc = Perform_cross_val(logreg, 5, x_train, y_train, 'accuracy')
cross10_acc = Perform_cross_val(logreg, 10, x_train, y_train, 'accuracy')
# Out:
# -------------------- CV for k=5, scoring=accuracy --------------------
# CV mean: 0.7622417699586832
# CV results: [0.71544715 0.82113821 0.73170732 0.76422764 0.77868852]
#
# -------------------- CV for k=10, scoring=accuracy --------------------
# CV mean: 0.7539925965097832
# CV results: [0.74193548 0.67741935 0.87096774 0.77419355 0.72131148 0.72131148
#  0.78688525 0.70491803 0.7704918  0.7704918 ]

# %% [markdown]
# The values of the folds are close to each other and no problem

# %% [markdown]
# Now create model for test_size = 0.2

# %%
# %matplotlib inline
parameters = dict(solver='liblinear' ,penalty='l2',C=1)
model, acc, features = modeling(x, y, 0.2, ['Diabetes disease=1', 'Not Diabetes disease=0'], parameters, is_add=1)
features
# Out:
# -------------------- Confusion Matrix --------------------
# [[28 19]
#  [10 97]]
# -------------------- Classification Report --------------------
#                         precision    recall  f1-score   support
#
#     Diabetes disease=1       0.84      0.91      0.87       107
# Not Diabetes disease=0       0.74      0.60      0.66        47
#
#               accuracy                           0.81       154
#              macro avg       0.79      0.75      0.76       154
#           weighted avg       0.81      0.81      0.81       154
#
#
# Jaccard Score: 0.49122807017543857
#
# -------------------- Feature --------------------
#                           Importance  Positive
# Features
# Intercept                  -0.786687     False
# BloodPressure              -0.168136     False
# Insulin                    -0.124854     False
# SkinThickness              -0.032333     False
# Age                         0.208669      True
# DiabetesPedigreeFunction    0.265662      True
# Pregnancies                 0.321907      True
# BMI                         0.656904      True
# Glucose                     1.125913      True

# %% [markdown]
# The obtained results are relatively good, but we will continue to improve the performance of the model

# %%
x
# Out:
#      Pregnancies   Glucose  BloodPressure  SkinThickness   Insulin       BMI  \
# 0       0.639947  0.866045      -0.033518       0.670643 -0.181541  0.166292
# 1      -0.844885 -1.205066      -0.529859      -0.012301 -0.181541 -0.852531
# 2       1.233880  2.016662      -0.695306      -0.012301 -0.181541 -1.332833
# 3      -0.844885 -1.073567      -0.529859      -0.695245 -0.540642 -0.634212
# 4      -1.141852  0.504422      -2.680669       0.670643  0.316566  1.548980
# ..           ...       ...            ...            ...       ...       ...
# 763     1.827813 -0.679069       0.297376       2.150354  0.455573  0.064409
# 764    -0.547919  0.011301      -0.198965      -0.239949 -0.181541  0.632039
# 765     0.342981 -0.021574      -0.033518      -0.695245 -0.332132 -0.910750
# 766    -0.844885  0.142800      -1.026200      -0.012301 -0.181541 -0.343120
# 767    -0.844885 -0.942068      -0.198965       0.215347 -0.181541 -0.299456
#
#      DiabetesPedigreeFunction       Age
# 0                    0.468492  1.425995
# 1                   -0.365061 -0.190672
# 2                    0.604397 -0.105584
# 3                   -0.920763 -1.041549
# 4                    5.484909 -0.020496
# ..                        ...       ...
# 763                 -0.908682  2.532136
# 764                 -0.398282 -0.531023
# 765                 -0.685193 -0.275760
# 766                 -0.371101  1.170732
# 767                 -0.473785 -0.871374
#
# [768 rows x 8 columns]

# %% [markdown]
# # <font color='orange'> 5.Improve Model </font>

# %%
# we improve model by ذringing some features to the power of 3
# we have negative number so we can not use dim=2
dim = 3
for col in features.index.tolist()[1:]:
    new_col = f"{col}_{dim}"
    x[new_col] = x[col] ** dim
    x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=0)
    logreg = LogisticRegression(solver='liblinear')
    logreg.fit(x_train, y_train)
    accuracy = metrics.accuracy_score(y_test, logreg.predict(x_test))
    if accuracy <= acc:
        x.drop(new_col, axis=1, inplace=True)
    else:
        acc = accuracy
        parameters = dict(solver='liblinear' ,penalty='l2',C=1)
        modeling(x, y, 0.2, ['Diabetes disease=1', 'Not Diabetes disease=0'], parameters, is_add=1)

# %%
x
# Out:
#      Pregnancies   Glucose  BloodPressure  SkinThickness   Insulin       BMI  \
# 0       0.639947  0.866045      -0.033518       0.670643 -0.181541  0.166292
# 1      -0.844885 -1.205066      -0.529859      -0.012301 -0.181541 -0.852531
# 2       1.233880  2.016662      -0.695306      -0.012301 -0.181541 -1.332833
# 3      -0.844885 -1.073567      -0.529859      -0.695245 -0.540642 -0.634212
# 4      -1.141852  0.504422      -2.680669       0.670643  0.316566  1.548980
# ..           ...       ...            ...            ...       ...       ...
# 763     1.827813 -0.679069       0.297376       2.150354  0.455573  0.064409
# 764    -0.547919  0.011301      -0.198965      -0.239949 -0.181541  0.632039
# 765     0.342981 -0.021574      -0.033518      -0.695245 -0.332132 -0.910750
# 766    -0.844885  0.142800      -1.026200      -0.012301 -0.181541 -0.343120
# 767    -0.844885 -0.942068      -0.198965       0.215347 -0.181541 -0.299456
#
#      DiabetesPedigreeFunction       Age
# 0                    0.468492  1.425995
# 1                   -0.365061 -0.190672
# 2                    0.604397 -0.105584
# 3                   -0.920763 -1.041549
# 4                    5.484909 -0.020496
# ..                        ...       ...
# 763                 -0.908682  2.532136
# 764                 -0.398282 -0.531023
# 765                 -0.685193 -0.275760
# 766                 -0.371101  1.170732
# 767                 -0.473785 -0.871374
#
# [768 rows x 8 columns]

# %% [markdown]
# Since the performance of the model did not change much, exponentiation has no effect.

# %% [markdown]
# Now tuning hyperparameter for logistic regression for improve model

# %%
# define models and parameters
model = LogisticRegression()
solvers = ['newton-cg', 'lbfgs', 'liblinear', 'sag', 'saga']
penalty = ['l2']
c_values = [100, 10, 1.0, 0.1, 0.01]
# define grid search
grid = dict(solver=solvers,penalty=penalty,C=c_values)
cv = RepeatedStratifiedKFold(n_splits=10, random_state=0)
grid_search = GridSearchCV(estimator=model, param_grid=grid, n_jobs=-1, cv=cv, scoring='accuracy',error_score=0)
grid_result = grid_search.fit(x_train, y_train)
# summarize results
print(f"Best: {grid_result.best_score_} using {grid_result.best_params_}")
means = grid_result.cv_results_['mean_test_score']
stds = grid_result.cv_results_['std_test_score']
params = grid_result.cv_results_['params']
for mean, stdev, param in zip(means, stds, params):
    print(f"{mean} ({stdev}) with: {param}")
# Out:
# Best: 0.7582707562136436 using {'C': 0.01, 'penalty': 'l2', 'solver': 'newton-cg'}
# 0.7577868852459015 (0.058276888692476665) with: {'C': 100, 'penalty': 'l2', 'solver': 'newton-cg'}
# 0.7577868852459015 (0.058276888692476665) with: {'C': 100, 'penalty': 'l2', 'solver': 'lbfgs'}
# 0.7577868852459015 (0.058276888692476665) with: {'C': 100, 'penalty': 'l2', 'solver': 'liblinear'}
# 0.7577868852459015 (0.058276888692476665) with: {'C': 100, 'penalty': 'l2', 'solver': 'sag'}
# 0.7577868852459015 (0.058276888692476665) with: {'C': 100, 'penalty': 'l2', 'solver': 'saga'}
# 0.7576229508196719 (0.05840218730112301) with: {'C': 10, 'penalty': 'l2', 'solver': 'newton-cg'}
# 0.7576229508196719 (0.05840218730112301) with: {'C': 10, 'penalty': 'l2', 'solver': 'lbfgs'}
# 0.7577868852459015 (0.058276888692476665) with: {'C': 10, 'penalty': 'l2', 'solver': 'liblinear'}
# 0.7576229508196719 (0.05840218730112301) with: {'C': 10, 'penalty': 'l2', 'solver': 'sag'}
# 0.7576229508196719 (0.05840218730112301) with: {'C': 10, 'penalty': 'l2', 'solver': 'saga'}
# 0.7579561078794286 (0.05768370236125601) with: {'C': 1.0, 'penalty': 'l2', 'solver': 'newton-cg'}
# 0.7577921734531992 (0.057577862331885665) with: {'C': 1.0, 'penalty': 'l2', 'solver': 'lbfgs'}
# 0.7576282390269696 (0.058070155345386065) with: {'C': 1.0, 'penalty': 'l2', 'solver': 'liblinear'}
# 0.7579561078794286 (0.05768370236125601) with: {'C': 1.0, 'penalty': 'l2', 'solver': 'sag'}
# 0.7579561078794286 (0.05768370236125601) with: {'C': 1.0, 'penalty': 'l2', 'solver': 'saga'}
# 0.7555235325224747 (0.05709284004466986) with: {'C': 0.1, 'penalty': 'l2', 'solver': 'newton-cg'}
# 0.7556874669487043 (0.056923510899569534) with: {'C': 0.1, 'penalty': 'l2', 'solver': 'lbfgs'}
# 0.7568138551031199 (0.05590704228683284) with: {'C': 0.1, 'penalty': 'l2', 'solver': 'liblinear'}
# 0.7556874669487043 (0.056923510899569534) with: {'C': 0.1, 'penalty': 'l2', 'solver': 'sag'}
# 0.7555235325224747 (0.05709284004466986) with: {'C': 0.1, 'penalty': 'l2', 'solver': 'saga'}
# 0.7582707562136436 (0.04713293429816737) with: {'C': 0.01, 'penalty': 'l2', 'solver': 'newton-cg'}
# 0.7582707562136436 (0.04713293429816737) with: {'C': 0.01, 'penalty': 'l2', 'solver': 'lbfgs'}
# 0.7541961924907458 (0.05205352582517698) with: {'C': 0.01, 'penalty': 'l2', 'solver': 'liblinear'}
# 0.7582707562136436 (0.04713293429816737) with: {'C': 0.01, 'penalty': 'l2', 'solver': 'sag'}
# 0.7582707562136436 (0.04713293429816737) with: {'C': 0.01, 'penalty': 'l2', 'solver': 'saga'}

# %%
parameters = dict(grid_result.best_params_)
model, _, features = modeling(x, y, 0.2, ['Diabetes disease=1', 'Not Diabetes disease=0'], parameters, is_add=1)
features
# Out:
# -------------------- Confusion Matrix --------------------
# [[ 25  22]
#  [  7 100]]
# -------------------- Classification Report --------------------
#                         precision    recall  f1-score   support
#
#     Diabetes disease=1       0.82      0.93      0.87       107
# Not Diabetes disease=0       0.78      0.53      0.63        47
#
#               accuracy                           0.81       154
#              macro avg       0.80      0.73      0.75       154
#           weighted avg       0.81      0.81      0.80       154
#
#
# Jaccard Score: 0.46296296296296297
#
# -------------------- Feature --------------------
#                           Importance  Positive
# Features
# Intercept                  -0.672717     False
# BloodPressure               0.022672      True
# Insulin                     0.065495      True
# SkinThickness               0.078959      True
# DiabetesPedigreeFunction    0.143078      True
# Pregnancies                 0.161962      True
# Age                         0.162977      True
# BMI                         0.292520      True
# Glucose                     0.513303      True

# %% [markdown]
# try imporve model by dot product some features

# %%
x['p_BloodPressure_Insulin'] = x.BloodPressure * x.Insulin
model, _, features = modeling(x, y, 0.2, ['Diabetes disease=1', 'Not Diabetes disease=0'], parameters, is_add=1)
# Out:
# -------------------- Confusion Matrix --------------------
# [[ 26  21]
#  [  5 102]]
# -------------------- Classification Report --------------------
#                         precision    recall  f1-score   support
#
#     Diabetes disease=1       0.83      0.95      0.89       107
# Not Diabetes disease=0       0.84      0.55      0.67        47
#
#               accuracy                           0.83       154
#              macro avg       0.83      0.75      0.78       154
#           weighted avg       0.83      0.83      0.82       154
#
#
# Jaccard Score: 0.5
#
# -------------------- Feature --------------------

# %% [markdown]
# Now testing model for test_size =0.3 and 0.25

# %%
model, _, features = modeling(x, y, 0.3, ['Diabetes disease=1', 'Not Diabetes disease=0'], parameters, is_add=1)
# Out:
# -------------------- Confusion Matrix --------------------
# [[ 34  40]
#  [ 10 147]]
# -------------------- Classification Report --------------------
#                         precision    recall  f1-score   support
#
#     Diabetes disease=1       0.79      0.94      0.85       157
# Not Diabetes disease=0       0.77      0.46      0.58        74
#
#               accuracy                           0.78       231
#              macro avg       0.78      0.70      0.72       231
#           weighted avg       0.78      0.78      0.77       231
#
#
# Jaccard Score: 0.40476190476190477
#
# -------------------- Feature --------------------

# %%
model, acc, features = modeling(x, y, 0.25, ['Diabetes disease=1', 'Not Diabetes disease=0'], parameters, is_add=1)
# Out:
# -------------------- Confusion Matrix --------------------
# [[ 30  32]
#  [  8 122]]
# -------------------- Classification Report --------------------
#                         precision    recall  f1-score   support
#
#     Diabetes disease=1       0.79      0.94      0.86       130
# Not Diabetes disease=0       0.79      0.48      0.60        62
#
#               accuracy                           0.79       192
#              macro avg       0.79      0.71      0.73       192
#           weighted avg       0.79      0.79      0.78       192
#
#
# Jaccard Score: 0.42857142857142855
#
# -------------------- Feature --------------------

# %% [markdown]
# As seen, the best model was the one obtained with a test size = 0.2

# %%
# for prevent repeat model 3 that has better result we
# delete model 3 and now fit model again as the final model so:
del FPR1[2]
del TPR1[2]
del FPR0[2]
del TPR0[2]
del ACC[2]
del Recall[2]
del Precision[2]
del F1[2]

# %%
# modeling final model that is better model
model, _, features = modeling(x, y, 0.2, ['Diabetes disease=1', 'Not Diabetes disease=0'], parameters, is_add=1)
features
# Out:
# -------------------- Confusion Matrix --------------------
# [[ 26  21]
#  [  5 102]]
# -------------------- Classification Report --------------------
#                         precision    recall  f1-score   support
#
#     Diabetes disease=1       0.83      0.95      0.89       107
# Not Diabetes disease=0       0.84      0.55      0.67        47
#
#               accuracy                           0.83       154
#              macro avg       0.83      0.75      0.78       154
#           weighted avg       0.83      0.83      0.82       154
#
#
# Jaccard Score: 0.5
#
# -------------------- Feature --------------------
#                           Importance  Positive
# Features
# Intercept                  -0.672501     False
# p_BloodPressure_Insulin    -0.069038     False
# BloodPressure               0.026617      True
# Insulin                     0.065771      True
# SkinThickness               0.080280      True
# DiabetesPedigreeFunction    0.144227      True
# Age                         0.161380      True
# Pregnancies                 0.161387      True
# BMI                         0.294559      True
# Glucose                     0.510646      True

# %% [markdown]
# So model 5 is our best model

# %% [markdown]
# # <font color='orange'> 6. Visualization Final Model </font>

# %%
# %matplotlib inline
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=0)
x_test.insert(9,'outcome', y_test)
cols = ['Age','BloodPressure','Insulin','SkinThickness','DiabetesPedigreeFunction','Pregnancies','BMI']
for col in cols:

    fig = px.scatter_3d(
        data_frame= x_test,
        x=x_test.Glucose,
        y=x_test[col],
        z=x_test.outcome,
        color=model.predict(x_test.drop('outcome', axis=1)).astype(str),
        color_discrete_sequence={0:'red', 1:'green'},
        template='ggplot2',
        hover_name='Age',
        # hover_data=
        opacity=0.6,
        # symbol='Transmission',
        # symbol_map=
        # log_x=True,
        # log_z=True,
        height=700,
        title=f'Visualization Performance of Model in Predicting')

    pio.show(fig)
# Out:
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.1.1.min.js" integrity="sha256-HUEFyfiTnZJxCxur99FjbKYTvKSzwDaD3/x5TqHpFu4=" crossorigin="anonymous"></script>                <div id="21a7123f-243e-49e7-a267-22c1bb5ac0cd" class="plotly-graph-div" style="height:700px; width:100%;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("21a7123f-243e-49e7-a267-22c1bb5ac0cd")) {                    Plotly.newPlot(                        "21a7123f-243e-49e7-a267-22c1bb5ac0cd",                        [{"hovertemplate":"\u003cb\u003e%{hovertext}\u003c\u002fb\u003e\u003cbr\u003e\u003cbr\u003ecolor=1\u003cbr\u003eGlucose=%{x}\u003cbr\u003eAge=%{y}\u003cbr\u003eoutcome=%{z}\u003cextra\u003e\u003c\u002fextra\u003e","hovertext":{"dtype":"f8","bdata":"0YY7iFWb7r\u002fu73OIZS34P9+RRwsC\u002fZS\u002f8f5DguqJ+T9apfWkM4rcv\u002fQNFHxv5vo\u002fDHYYKtcMzj8Sd0x8f3jUPyrvzEqnXN8\u002fobOmjGcg5T+\u002fLFutN3Dmv\u002fQNFHxv5vo\u002fHrOMY5Pq2T9apfWkM4rcv63v5nN7kuo\u002fTmm1vR8Y178q78xKp1zfP+jR05RbdPU\u002f3JWTrUcC8D+5Dru5LbfjvyrvzEqnXN8\u002f7u9ziGUt+D\u002fr4KOO4ND2P\u002f06hGn++\u002f4\u002fqNTSH5AHu7\u002fRhjuIVZvuv+KzM6FRu\u002fI\u002fxUr7oEEp6b\u002flwgOb1hf0P1ql9aQzity\u002f0YY7iFWb7r8="},"legendgroup":"1","marker":{"color":"red","opacity":0.6,"symbol":"circle"},"mode":"markers","name":"1","scene":"scene","showlegend":true,"x":{"dtype":"f8","bdata":"q1rjHV1XBECmr2dEHFP3P8yvQAzh6+8\u002fClwIOqmV\u002fD\u002fvWBqz3h3zP6JZ6fBuLwFAjlyFUKAp\u002fj9fAqbpZYHnP70CSjiYfPA\u002fUwW7qGtg+D8nWmYHZsMCQNSvuWu10ANAH1rtp5He7j8vySrPYQLMv3xakfbD2fc\u002fE10CZ5e9\u002fz\u002fUr7lrtdADQM8EPpJ0zPY\u002f9QOWjB8iAEDYBTi\u002fYvT5P5Stc+o\u002fA\u002fE\u002fPLLYtO82\u002fz\u002f4WRTgzEX2PwQSMAqsa9a\u002f9QOWjB8iAECFW4sjsgH7P3RZl8nVsfQ\u002fJ1pmB2bDAkB5XqDit+Crv66wYXEKe\u002fo\u002fBFf\u002fIMdm5T8="},"y":{"dtype":"f8","bdata":"0YY7iFWb7r\u002fu73OIZS34P9+RRwsC\u002fZS\u002f8f5DguqJ+T9apfWkM4rcv\u002fQNFHxv5vo\u002fDHYYKtcMzj8Sd0x8f3jUPyrvzEqnXN8\u002fobOmjGcg5T+\u002fLFutN3Dmv\u002fQNFHxv5vo\u002fHrOMY5Pq2T9apfWkM4rcv63v5nN7kuo\u002fTmm1vR8Y178q78xKp1zfP+jR05RbdPU\u002f3JWTrUcC8D+5Dru5LbfjvyrvzEqnXN8\u002f7u9ziGUt+D\u002fr4KOO4ND2P\u002f06hGn++\u002f4\u002fqNTSH5AHu7\u002fRhjuIVZvuv+KzM6FRu\u002fI\u002fxUr7oEEp6b\u002flwgOb1hf0P1ql9aQzity\u002f0YY7iFWb7r8="},"z":{"dtype":"i1","bdata":"AQEBAQEBAQEAAQEBAQEBAQEBAAEAAQABAQEBAAEBAQ=="},"type":"scatter3d"},{"hovertemplate":"\u003cb\u003e%{hovertext}\u003c\u002fb\u003e\u003cbr\u003e\u003cbr\u003ecolor=0\u003cbr\u003eGlucose=%{x}\u003cbr\u003eAge=%{y}\u003cbr\u003eoutcome=%{z}\u003cextra\u003e\u003c\u002fextra\u003e","hovertext":{"dtype":"f8","bdata":"y2iblEvi67+\u002fLFutN3Dmv2ziad7vZ8i\u002fxUr7oEEp6b+\u002fLFutN3Dmv\u002fortG95n\u002f0\u002fACWqsUEsAEC\u002fLFutN3Dmv6fRRoBx2ec\u002fqNTSH5AHu79r0u29L6rwvwlSGp\u002fQQQRAQi111gum0b9r0u29L6rwv78sW603cOa\u002f36Rjp8xe8T\u002fRhjuIVZvuv2vS7b0vqvC\u002fs\u002fAaxiP+4L\u002fFSvugQSnpv0ItddYLptG\u002f7u9ziGUt+D9r0u29L6rwv7PwGsYj\u002fuC\u002fWqX1pDOK3L\u002fFSvugQSnpv6fRRoBx2ec\u002fa9LtvS+q8L+\u002fLFutN3Dmv7kOu7ktt+O\u002fy2iblEvi679r0u29L6rwv6jU0h+QB7u\u002fa9LtvS+q8L9r0u29L6rwv1ql9aQzity\u002fuQ67uS2347+z8BrGI\u002f7gvwx2GCrXDM4\u002f0YY7iFWb7r8q78xKp1zfP78sW603cOa\u002f0YY7iFWb7r9s4mne72fIv8tom5RL4uu\u002fQi111gum0b9CLXXWC6bRv2vS7b0vqvC\u002fvyxbrTdw5r+blQaZXWfiP6fRRoBx2ec\u002fHrOMY5Pq2T9r0u29L6rwvxJ3THx\u002feNQ\u002fvyxbrTdw5r9CLXXWC6bRv+KzM6FRu\u002fI\u002fuAsvGg+JsD9CLXXWC6bRv6fRRoBx2ec\u002fxUr7oEEp6b+z8BrGI\u002f7gv2vS7b0vqvC\u002fWqX1pDOK3L9OabW9HxjXv9GGO4hVm+6\u002f35FHCwL9lL9r0u29L6rwv0ItddYLptG\u002fs\u002fAaxiP+4L+\u002fLFutN3Dmv9GGO4hVm+6\u002f0YY7iFWb7r+o1NIfkAe7v7PwGsYj\u002fuC\u002f36Rjp8xe8T+z8BrGI\u002f7gv2vS7b0vqvC\u002fQi111gum0b+\u002fLFutN3Dmv8VK+6BBKem\u002f35FHCwL9lL9r0u29L6rwv9GGO4hVm+6\u002fQi111gum0b\u002fRhjuIVZvuvwx2GCrXDM4\u002fobOmjGcg5T\u002ffkUcLAv2Uv9GGO4hVm+6\u002fy2iblEvi678es4xjk+rZPwxh6phVngVAWqX1pDOK3L+ISjIijpMDQGvS7 ...
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.1.1.min.js" integrity="sha256-HUEFyfiTnZJxCxur99FjbKYTvKSzwDaD3/x5TqHpFu4=" crossorigin="anonymous"></script>                <div id="77692ff1-ac0b-4681-8b41-e2146c7245a1" class="plotly-graph-div" style="height:700px; width:100%;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("77692ff1-ac0b-4681-8b41-e2146c7245a1")) {                    Plotly.newPlot(                        "77692ff1-ac0b-4681-8b41-e2146c7245a1",                        [{"hovertemplate":"\u003cb\u003e%{hovertext}\u003c\u002fb\u003e\u003cbr\u003e\u003cbr\u003ecolor=1\u003cbr\u003eGlucose=%{x}\u003cbr\u003eBloodPressure=%{y}\u003cbr\u003eoutcome=%{z}\u003cextra\u003e\u003c\u002fextra\u003e","hovertext":{"dtype":"f8","bdata":"0YY7iFWb7r\u002fu73OIZS34P9+RRwsC\u002fZS\u002f8f5DguqJ+T9apfWkM4rcv\u002fQNFHxv5vo\u002fDHYYKtcMzj8Sd0x8f3jUPyrvzEqnXN8\u002fobOmjGcg5T+\u002fLFutN3Dmv\u002fQNFHxv5vo\u002fHrOMY5Pq2T9apfWkM4rcv63v5nN7kuo\u002fTmm1vR8Y178q78xKp1zfP+jR05RbdPU\u002f3JWTrUcC8D+5Dru5LbfjvyrvzEqnXN8\u002f7u9ziGUt+D\u002fr4KOO4ND2P\u002f06hGn++\u002f4\u002fqNTSH5AHu7\u002fRhjuIVZvuv+KzM6FRu\u002fI\u002fxUr7oEEp6b\u002flwgOb1hf0P1ql9aQzity\u002f0YY7iFWb7r8="},"legendgroup":"1","marker":{"color":"red","opacity":0.6,"symbol":"circle"},"mode":"markers","name":"1","scene":"scene","showlegend":true,"x":{"dtype":"f8","bdata":"q1rjHV1XBECmr2dEHFP3P8yvQAzh6+8\u002fClwIOqmV\u002fD\u002fvWBqz3h3zP6JZ6fBuLwFAjlyFUKAp\u002fj9fAqbpZYHnP70CSjiYfPA\u002fUwW7qGtg+D8nWmYHZsMCQNSvuWu10ANAH1rtp5He7j8vySrPYQLMv3xakfbD2fc\u002fE10CZ5e9\u002fz\u002fUr7lrtdADQM8EPpJ0zPY\u002f9QOWjB8iAEDYBTi\u002fYvT5P5Stc+o\u002fA\u002fE\u002fPLLYtO82\u002fz\u002f4WRTgzEX2PwQSMAqsa9a\u002f9QOWjB8iAECFW4sjsgH7P3RZl8nVsfQ\u002fJ1pmB2bDAkB5XqDit+Crv66wYXEKe\u002fo\u002fBFf\u002fIMdm5T8="},"y":{"dtype":"f8","bdata":"j2ddxDMI0z\u002f1Qfp5TSmhv3a\u002fK37int0\u002fxUdZWWf+8T+PZ13EMwjTP49nXcQzCNM\u002f9UH6eU0pob+iN+T4H2bpP77dzAcTpPQ\u002f7VM8S\u002fI\u002f5r9LQBvSsHfJv0tAG9Kwd8m\u002fS0Ab0rB3yb\u002fPZQe4NvAAQMOR7hSOOwZAUR8eFQrjwD9RHx4VCuPAP77dzAcTpPQ\u002fq58nExaV\u002fD\u002f1Qfp5TSmhv1EfHhUK48A\u002flmPLVXex7j+iN+T4H2bpP\u002fVB+nlNKaG\u002f7VM8S\u002fI\u002f5r+WY8tVd7HuP8VHWVln\u002fvE\u002fy0PH6qqn\u002fb+vC\u002f2byBrkPw342yKHUte\u002fxUdZWWf+8T8="},"z":{"dtype":"i1","bdata":"AQEBAQEBAQEAAQEBAQEBAQEBAAEAAQABAQEBAAEBAQ=="},"type":"scatter3d"},{"hovertemplate":"\u003cb\u003e%{hovertext}\u003c\u002fb\u003e\u003cbr\u003e\u003cbr\u003ecolor=0\u003cbr\u003eGlucose=%{x}\u003cbr\u003eBloodPressure=%{y}\u003cbr\u003eoutcome=%{z}\u003cextra\u003e\u003c\u002fextra\u003e","hovertext":{"dtype":"f8","bdata":"y2iblEvi67+\u002fLFutN3Dmv2ziad7vZ8i\u002fxUr7oEEp6b+\u002fLFutN3Dmv\u002fortG95n\u002f0\u002fACWqsUEsAEC\u002fLFutN3Dmv6fRRoBx2ec\u002fqNTSH5AHu79r0u29L6rwvwlSGp\u002fQQQRAQi111gum0b9r0u29L6rwv78sW603cOa\u002f36Rjp8xe8T\u002fRhjuIVZvuv2vS7b0vqvC\u002fs\u002fAaxiP+4L\u002fFSvugQSnpv0ItddYLptG\u002f7u9ziGUt+D9r0u29L6rwv7PwGsYj\u002fuC\u002fWqX1pDOK3L\u002fFSvugQSnpv6fRRoBx2ec\u002fa9LtvS+q8L+\u002fLFutN3Dmv7kOu7ktt+O\u002fy2iblEvi679r0u29L6rwv6jU0h+QB7u\u002fa9LtvS+q8L9r0u29L6rwv1ql9aQzity\u002fuQ67uS2347+z8BrGI\u002f7gvwx2GCrXDM4\u002f0YY7iFWb7r8q78xKp1zfP78sW603cOa\u002f0YY7iFWb7r9s4mne72fIv8tom5RL4uu\u002fQi111gum0b9CLXXWC6bRv2vS7b0vqvC\u002fvyxbrTdw5r+blQaZXWfiP6fRRoBx2ec\u002fHrOMY5Pq2T9r0u29L6rwvxJ3THx\u002feNQ\u002fvyxbrTdw5r9CLXXWC6bRv+KzM6FRu\u002fI\u002fuAsvGg+JsD9CLXXWC6bRv6fRRoBx2ec\u002fxUr7oEEp6b+z8BrGI\u002f7gv2vS7b0vqvC\u002fWqX1pDOK3L9OabW9HxjXv9GGO4hVm+6\u002f35FHCwL9lL9r0u29L6rwv0ItddYLptG\u002fs\u002fAaxiP+4L+\u002fLFutN3Dmv9GGO4hVm+6\u002f0YY7iFWb7r+o1NIfkAe7v7PwGsYj\u002fuC\u002f36Rjp8xe8T+z8BrGI\u002f7gv2vS7b0vqvC\u002fQi111gum0b+\u002fLFutN3Dmv8VK+6BBKem\u002f35FHCwL9lL9r0u29L6rwv9GGO4hVm+6\u002fQi111gum0b\u002fRhjuIVZvuvwx2GCrXDM4\u002fobOmjGcg5T\u002ffkUcLAv2Uv9GGO4hVm+6\u002fy2iblEvi678es4xjk+rZPwxh6phVngVA ...
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.1.1.min.js" integrity="sha256-HUEFyfiTnZJxCxur99FjbKYTvKSzwDaD3/x5TqHpFu4=" crossorigin="anonymous"></script>                <div id="5148b090-4de4-47dd-9341-376196598d0e" class="plotly-graph-div" style="height:700px; width:100%;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("5148b090-4de4-47dd-9341-376196598d0e")) {                    Plotly.newPlot(                        "5148b090-4de4-47dd-9341-376196598d0e",                        [{"hovertemplate":"\u003cb\u003e%{hovertext}\u003c\u002fb\u003e\u003cbr\u003e\u003cbr\u003ecolor=1\u003cbr\u003eGlucose=%{x}\u003cbr\u003eInsulin=%{y}\u003cbr\u003eoutcome=%{z}\u003cextra\u003e\u003c\u002fextra\u003e","hovertext":{"dtype":"f8","bdata":"0YY7iFWb7r\u002fu73OIZS34P9+RRwsC\u002fZS\u002f8f5DguqJ+T9apfWkM4rcv\u002fQNFHxv5vo\u002fDHYYKtcMzj8Sd0x8f3jUPyrvzEqnXN8\u002fobOmjGcg5T+\u002fLFutN3Dmv\u002fQNFHxv5vo\u002fHrOMY5Pq2T9apfWkM4rcv63v5nN7kuo\u002fTmm1vR8Y178q78xKp1zfP+jR05RbdPU\u002f3JWTrUcC8D+5Dru5LbfjvyrvzEqnXN8\u002f7u9ziGUt+D\u002fr4KOO4ND2P\u002f06hGn++\u002f4\u002fqNTSH5AHu7\u002fRhjuIVZvuv+KzM6FRu\u002fI\u002fxUr7oEEp6b\u002flwgOb1hf0P1ql9aQzity\u002f0YY7iFWb7r8="},"legendgroup":"1","marker":{"color":"red","opacity":0.6,"symbol":"circle"},"mode":"markers","name":"1","scene":"scene","showlegend":true,"x":{"dtype":"f8","bdata":"q1rjHV1XBECmr2dEHFP3P8yvQAzh6+8\u002fClwIOqmV\u002fD\u002fvWBqz3h3zP6JZ6fBuLwFAjlyFUKAp\u002fj9fAqbpZYHnP70CSjiYfPA\u002fUwW7qGtg+D8nWmYHZsMCQNSvuWu10ANAH1rtp5He7j8vySrPYQLMv3xakfbD2fc\u002fE10CZ5e9\u002fz\u002fUr7lrtdADQM8EPpJ0zPY\u002f9QOWjB8iAEDYBTi\u002fYvT5P5Stc+o\u002fA\u002fE\u002fPLLYtO82\u002fz\u002f4WRTgzEX2PwQSMAqsa9a\u002f9QOWjB8iAECFW4sjsgH7P3RZl8nVsfQ\u002fJ1pmB2bDAkB5XqDit+Crv66wYXEKe\u002fo\u002fBFf\u002fIMdm5T8="},"y":{"dtype":"f8","bdata":"hDd4Ur48x7\u002fmEMgzJnPZP88hLtD8e9Y\u002fa8JZNUO6xj9BerOgHlbzP9LES6g4lug\u002fkcPusq2lv7+EN3hSvjzHvz\u002fKtu784H+\u002fhDd4Ur48x7+EN3hSvjzHv9ef8V9gpBJAyJ6N4sEn+D+EN3hSvjzHvwzJjGnavfA\u002fhDd4Ur48x7+EN3hSvjzHv4Q3eFK+PMe\u002fhDd4Ur48x7+EN3hSvjzHv2hi\u002fjmwZeM\u002fhSSLDcsG4z9NE7qmG0\u002frv9LES6g4lug\u002fhDd4Ur48x78iVB+Bz+MOQIQ3eFK+PMe\u002fcRj7dCe3BUBJ6hcVjqm7P1Q2+KdnTxRAhDd4Ur48x78="},"z":{"dtype":"i1","bdata":"AQEBAQEBAQEAAQEBAQEBAQEBAAEAAQABAQEBAAEBAQ=="},"type":"scatter3d"},{"hovertemplate":"\u003cb\u003e%{hovertext}\u003c\u002fb\u003e\u003cbr\u003e\u003cbr\u003ecolor=0\u003cbr\u003eGlucose=%{x}\u003cbr\u003eInsulin=%{y}\u003cbr\u003eoutcome=%{z}\u003cextra\u003e\u003c\u002fextra\u003e","hovertext":{"dtype":"f8","bdata":"y2iblEvi67+\u002fLFutN3Dmv2ziad7vZ8i\u002fxUr7oEEp6b+\u002fLFutN3Dmv\u002fortG95n\u002f0\u002fACWqsUEsAEC\u002fLFutN3Dmv6fRRoBx2ec\u002fqNTSH5AHu79r0u29L6rwvwlSGp\u002fQQQRAQi111gum0b9r0u29L6rwv78sW603cOa\u002f36Rjp8xe8T\u002fRhjuIVZvuv2vS7b0vqvC\u002fs\u002fAaxiP+4L\u002fFSvugQSnpv0ItddYLptG\u002f7u9ziGUt+D9r0u29L6rwv7PwGsYj\u002fuC\u002fWqX1pDOK3L\u002fFSvugQSnpv6fRRoBx2ec\u002fa9LtvS+q8L+\u002fLFutN3Dmv7kOu7ktt+O\u002fy2iblEvi679r0u29L6rwv6jU0h+QB7u\u002fa9LtvS+q8L9r0u29L6rwv1ql9aQzity\u002fuQ67uS2347+z8BrGI\u002f7gvwx2GCrXDM4\u002f0YY7iFWb7r8q78xKp1zfP78sW603cOa\u002f0YY7iFWb7r9s4mne72fIv8tom5RL4uu\u002fQi111gum0b9CLXXWC6bRv2vS7b0vqvC\u002fvyxbrTdw5r+blQaZXWfiP6fRRoBx2ec\u002fHrOMY5Pq2T9r0u29L6rwvxJ3THx\u002feNQ\u002fvyxbrTdw5r9CLXXWC6bRv+KzM6FRu\u002fI\u002fuAsvGg+JsD9CLXXWC6bRv6fRRoBx2ec\u002fxUr7oEEp6b+z8BrGI\u002f7gv2vS7b0vqvC\u002fWqX1pDOK3L9OabW9HxjXv9GGO4hVm+6\u002f35FHCwL9lL9r0u29L6rwv0ItddYLptG\u002fs\u002fAaxiP+4L+\u002fLFutN3Dmv9GGO4hVm+6\u002f0YY7iFWb7r+o1NIfkAe7v7PwGsYj\u002fuC\u002f36Rjp8xe8T+z8BrGI\u002f7gv2vS7b0vqvC\u002fQi111gum0b+\u002fLFutN3Dmv8VK+6BBKem\u002f35FHCwL9lL9r0u29L6rwv9GGO4hVm+6\u002fQi111gum0b\u002fRhjuIVZvuvwx2GCrXDM4\u002fobOmjGcg5T\u002ffkUcLAv2Uv9GGO4hVm+6\u002fy2iblEvi678es4xjk+rZPwxh6phVngVAWqX1pDOK3L+ISjIijpMDQGvS7b0vqvC\u002fvyxbrTdw5r9apfWkM4rcv\u00 ...
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.1.1.min.js" integrity="sha256-HUEFyfiTnZJxCxur99FjbKYTvKSzwDaD3/x5TqHpFu4=" crossorigin="anonymous"></script>                <div id="2ff2f2f3-ea1e-4153-a6ff-ddc0cc38e813" class="plotly-graph-div" style="height:700px; width:100%;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("2ff2f2f3-ea1e-4153-a6ff-ddc0cc38e813")) {                    Plotly.newPlot(                        "2ff2f2f3-ea1e-4153-a6ff-ddc0cc38e813",                        [{"hovertemplate":"\u003cb\u003e%{hovertext}\u003c\u002fb\u003e\u003cbr\u003e\u003cbr\u003ecolor=1\u003cbr\u003eGlucose=%{x}\u003cbr\u003eSkinThickness=%{y}\u003cbr\u003eoutcome=%{z}\u003cextra\u003e\u003c\u002fextra\u003e","hovertext":{"dtype":"f8","bdata":"0YY7iFWb7r\u002fu73OIZS34P9+RRwsC\u002fZS\u002f8f5DguqJ+T9apfWkM4rcv\u002fQNFHxv5vo\u002fDHYYKtcMzj8Sd0x8f3jUPyrvzEqnXN8\u002fobOmjGcg5T+\u002fLFutN3Dmv\u002fQNFHxv5vo\u002fHrOMY5Pq2T9apfWkM4rcv63v5nN7kuo\u002fTmm1vR8Y178q78xKp1zfP+jR05RbdPU\u002f3JWTrUcC8D+5Dru5LbfjvyrvzEqnXN8\u002f7u9ziGUt+D\u002fr4KOO4ND2P\u002f06hGn++\u002f4\u002fqNTSH5AHu7\u002fRhjuIVZvuv+KzM6FRu\u002fI\u002fxUr7oEEp6b\u002flwgOb1hf0P1ql9aQzity\u002f0YY7iFWb7r8="},"legendgroup":"1","marker":{"color":"red","opacity":0.6,"symbol":"circle"},"mode":"markers","name":"1","scene":"scene","showlegend":true,"x":{"dtype":"f8","bdata":"q1rjHV1XBECmr2dEHFP3P8yvQAzh6+8\u002fClwIOqmV\u002fD\u002fvWBqz3h3zP6JZ6fBuLwFAjlyFUKAp\u002fj9fAqbpZYHnP70CSjiYfPA\u002fUwW7qGtg+D8nWmYHZsMCQNSvuWu10ANAH1rtp5He7j8vySrPYQLMv3xakfbD2fc\u002fE10CZ5e9\u002fz\u002fUr7lrtdADQM8EPpJ0zPY\u002f9QOWjB8iAEDYBTi\u002fYvT5P5Stc+o\u002fA\u002fE\u002fPLLYtO82\u002fz\u002f4WRTgzEX2PwQSMAqsa9a\u002f9QOWjB8iAECFW4sjsgH7P3RZl8nVsfQ\u002fJ1pmB2bDAkB5XqDit+Crv66wYXEKe\u002fo\u002fBFf\u002fIMdm5T8="},"y":{"dtype":"f8","bdata":"jcwpVLxM+T\u002f2R+uqnWjyv7jJAyl10eE\u002fUl53BKi2zr\u002fN9zF+WRrpP1JedwSots6\u002fB0HePoN69z9EN6unIRHVP9gOyajLvuw\u002frl\u002fq+2oxib9cEvqkepDLP5jjwH4u8fw\u002f\u002fClHFBHW8z+uX+r7ajGJvx1vDJRnw\u002f4\u002frl\u002fq+2oxib+uX+r7ajGJv65f6vtqMYm\u002frl\u002fq+2oxib+uX+r7ajGJv0Q3q6chEdU\u002f1mGoAFeI7b+NzClUvEz5P1H9q1TQSgBArl\u002fq+2oxib9ZZdn8BVrcP65f6vtqMYm\u002fhurN6kjf97\u002fYDsmoy77sP9eI92kJHQJArl\u002fq+2oxib8="},"z":{"dtype":"i1","bdata":"AQEBAQEBAQEAAQEBAQEBAQEBAAEAAQABAQEBAAEBAQ=="},"type":"scatter3d"},{"hovertemplate":"\u003cb\u003e%{hovertext}\u003c\u002fb\u003e\u003cbr\u003e\u003cbr\u003ecolor=0\u003cbr\u003eGlucose=%{x}\u003cbr\u003eSkinThickness=%{y}\u003cbr\u003eoutcome=%{z}\u003cextra\u003e\u003c\u002fextra\u003e","hovertext":{"dtype":"f8","bdata":"y2iblEvi67+\u002fLFutN3Dmv2ziad7vZ8i\u002fxUr7oEEp6b+\u002fLFutN3Dmv\u002fortG95n\u002f0\u002fACWqsUEsAEC\u002fLFutN3Dmv6fRRoBx2ec\u002fqNTSH5AHu79r0u29L6rwvwlSGp\u002fQQQRAQi111gum0b9r0u29L6rwv78sW603cOa\u002f36Rjp8xe8T\u002fRhjuIVZvuv2vS7b0vqvC\u002fs\u002fAaxiP+4L\u002fFSvugQSnpv0ItddYLptG\u002f7u9ziGUt+D9r0u29L6rwv7PwGsYj\u002fuC\u002fWqX1pDOK3L\u002fFSvugQSnpv6fRRoBx2ec\u002fa9LtvS+q8L+\u002fLFutN3Dmv7kOu7ktt+O\u002fy2iblEvi679r0u29L6rwv6jU0h+QB7u\u002fa9LtvS+q8L9r0u29L6rwv1ql9aQzity\u002fuQ67uS2347+z8BrGI\u002f7gvwx2GCrXDM4\u002f0YY7iFWb7r8q78xKp1zfP78sW603cOa\u002f0YY7iFWb7r9s4mne72fIv8tom5RL4uu\u002fQi111gum0b9CLXXWC6bRv2vS7b0vqvC\u002fvyxbrTdw5r+blQaZXWfiP6fRRoBx2ec\u002fHrOMY5Pq2T9r0u29L6rwvxJ3THx\u002feNQ\u002fvyxbrTdw5r9CLXXWC6bRv+KzM6FRu\u002fI\u002fuAsvGg+JsD9CLXXWC6bRv6fRRoBx2ec\u002fxUr7oEEp6b+z8BrGI\u002f7gv2vS7b0vqvC\u002fWqX1pDOK3L9OabW9HxjXv9GGO4hVm+6\u002f35FHCwL9lL9r0u29L6rwv0ItddYLptG\u002fs\u002fAaxiP+4L+\u002fLFutN3Dmv9GGO4hVm+6\u002f0YY7iFWb7r+o1NIfkAe7v7PwGsYj\u002fuC\u002f36Rjp8xe8T+z8BrGI\u002f7gv2vS7b0vqvC\u002fQi111gum0b+\u002fLFutN3Dmv8VK+6BBKem\u002f35FHCwL9lL9r0u29L6rwv9GGO4hVm+6\u002fQi111gum0b\u002fRhjuIVZvuvwx2GCrXDM4\u002fobOmjGcg5T\u002ffkUcLAv2Uv9GGO4hVm+6\u002fy2iblEvi678es4xjk+rZPwxh6phVngVAWqX1pDOK3L+ISjIijpMD ...
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.1.1.min.js" integrity="sha256-HUEFyfiTnZJxCxur99FjbKYTvKSzwDaD3/x5TqHpFu4=" crossorigin="anonymous"></script>                <div id="1bb1217b-453a-4b94-ad3f-49591b029772" class="plotly-graph-div" style="height:700px; width:100%;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("1bb1217b-453a-4b94-ad3f-49591b029772")) {                    Plotly.newPlot(                        "1bb1217b-453a-4b94-ad3f-49591b029772",                        [{"hovertemplate":"\u003cb\u003e%{hovertext}\u003c\u002fb\u003e\u003cbr\u003e\u003cbr\u003ecolor=1\u003cbr\u003eGlucose=%{x}\u003cbr\u003eDiabetesPedigreeFunction=%{y}\u003cbr\u003eoutcome=%{z}\u003cextra\u003e\u003c\u002fextra\u003e","hovertext":{"dtype":"f8","bdata":"0YY7iFWb7r\u002fu73OIZS34P9+RRwsC\u002fZS\u002f8f5DguqJ+T9apfWkM4rcv\u002fQNFHxv5vo\u002fDHYYKtcMzj8Sd0x8f3jUPyrvzEqnXN8\u002fobOmjGcg5T+\u002fLFutN3Dmv\u002fQNFHxv5vo\u002fHrOMY5Pq2T9apfWkM4rcv63v5nN7kuo\u002fTmm1vR8Y178q78xKp1zfP+jR05RbdPU\u002f3JWTrUcC8D+5Dru5LbfjvyrvzEqnXN8\u002f7u9ziGUt+D\u002fr4KOO4ND2P\u002f06hGn++\u002f4\u002fqNTSH5AHu7\u002fRhjuIVZvuv+KzM6FRu\u002fI\u002fxUr7oEEp6b\u002flwgOb1hf0P1ql9aQzity\u002f0YY7iFWb7r8="},"legendgroup":"1","marker":{"color":"red","opacity":0.6,"symbol":"circle"},"mode":"markers","name":"1","scene":"scene","showlegend":true,"x":{"dtype":"f8","bdata":"q1rjHV1XBECmr2dEHFP3P8yvQAzh6+8\u002fClwIOqmV\u002fD\u002fvWBqz3h3zP6JZ6fBuLwFAjlyFUKAp\u002fj9fAqbpZYHnP70CSjiYfPA\u002fUwW7qGtg+D8nWmYHZsMCQNSvuWu10ANAH1rtp5He7j8vySrPYQLMv3xakfbD2fc\u002fE10CZ5e9\u002fz\u002fUr7lrtdADQM8EPpJ0zPY\u002f9QOWjB8iAEDYBTi\u002fYvT5P5Stc+o\u002fA\u002fE\u002fPLLYtO82\u002fz\u002f4WRTgzEX2PwQSMAqsa9a\u002f9QOWjB8iAECFW4sjsgH7P3RZl8nVsfQ\u002fJ1pmB2bDAkB5XqDit+Crv66wYXEKe\u002fo\u002fBFf\u002fIMdm5T8="},"y":{"dtype":"f8","bdata":"VAkbtoVHBkB4vNPwgUDWP1WfHJ54WfQ\u002f32n81RJ7AEBStN4C6lHyP0w02suyKfs\u002fcKMTfwri5z\u002fFs\u002f1aOr\u002fPP39MVBPH9gBAXUcc8ktH8L8olyQ2EVDmv6ziPf2NVe6\u002ff08OZhQb6j\u002fup\u002fDxxWfpvwA\u002fKXReqO2\u002fRcGapwuG2L+6ZkUU7V8BQC2XJ7DgauC\u002fHdpnUO7lB0C3syTT3weWPy1xqB94vfE\u002fbPsWpQYP1j90xY3W+EvZv86oPBDILgZAzuo\u002fCzlX4z8+LmAyeavkvwA\u002fKXReqO2\u002f5IF7B6Gy4T8LhmhC70LuP4Y6T3tyPeY\u002fprzLjDi74D8="},"z":{"dtype":"i1","bdata":"AQEBAQEBAQEAAQEBAQEBAQEBAAEAAQABAQEBAAEBAQ=="},"type":"scatter3d"},{"hovertemplate":"\u003cb\u003e%{hovertext}\u003c\u002fb\u003e\u003cbr\u003e\u003cbr\u003ecolor=0\u003cbr\u003eGlucose=%{x}\u003cbr\u003eDiabetesPedigreeFunction=%{y}\u003cbr\u003eoutcome=%{z}\u003cextra\u003e\u003c\u002fextra\u003e","hovertext":{"dtype":"f8","bdata":"y2iblEvi67+\u002fLFutN3Dmv2ziad7vZ8i\u002fxUr7oEEp6b+\u002fLFutN3Dmv\u002fortG95n\u002f0\u002fACWqsUEsAEC\u002fLFutN3Dmv6fRRoBx2ec\u002fqNTSH5AHu79r0u29L6rwvwlSGp\u002fQQQRAQi111gum0b9r0u29L6rwv78sW603cOa\u002f36Rjp8xe8T\u002fRhjuIVZvuv2vS7b0vqvC\u002fs\u002fAaxiP+4L\u002fFSvugQSnpv0ItddYLptG\u002f7u9ziGUt+D9r0u29L6rwv7PwGsYj\u002fuC\u002fWqX1pDOK3L\u002fFSvugQSnpv6fRRoBx2ec\u002fa9LtvS+q8L+\u002fLFutN3Dmv7kOu7ktt+O\u002fy2iblEvi679r0u29L6rwv6jU0h+QB7u\u002fa9LtvS+q8L9r0u29L6rwv1ql9aQzity\u002fuQ67uS2347+z8BrGI\u002f7gvwx2GCrXDM4\u002f0YY7iFWb7r8q78xKp1zfP78sW603cOa\u002f0YY7iFWb7r9s4mne72fIv8tom5RL4uu\u002fQi111gum0b9CLXXWC6bRv2vS7b0vqvC\u002fvyxbrTdw5r+blQaZXWfiP6fRRoBx2ec\u002fHrOMY5Pq2T9r0u29L6rwvxJ3THx\u002feNQ\u002fvyxbrTdw5r9CLXXWC6bRv+KzM6FRu\u002fI\u002fuAsvGg+JsD9CLXXWC6bRv6fRRoBx2ec\u002fxUr7oEEp6b+z8BrGI\u002f7gv2vS7b0vqvC\u002fWqX1pDOK3L9OabW9HxjXv9GGO4hVm+6\u002f35FHCwL9lL9r0u29L6rwv0ItddYLptG\u002fs\u002fAaxiP+4L+\u002fLFutN3Dmv9GGO4hVm+6\u002f0YY7iFWb7r+o1NIfkAe7v7PwGsYj\u002fuC\u002f36Rjp8xe8T+z8BrGI\u002f7gv2vS7b0vqvC\u002fQi111gum0b+\u002fLFutN3Dmv8VK+6BBKem\u002f35FHCwL9lL9r0u29L6rwv9GGO4hVm+6\u002fQi111gum0b\u002fRhjuIVZvuvwx2GCrXDM4\u002fobOmjGcg5T\u002ffkUcLAv2Uv9GGO4hVm+6\u002fy2iblEvi678es4xjk+rZPwxh6phVngVAWqX1pDOK ...
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.1.1.min.js" integrity="sha256-HUEFyfiTnZJxCxur99FjbKYTvKSzwDaD3/x5TqHpFu4=" crossorigin="anonymous"></script>                <div id="906c580a-8ab2-4617-b588-b02e3bce17f3" class="plotly-graph-div" style="height:700px; width:100%;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("906c580a-8ab2-4617-b588-b02e3bce17f3")) {                    Plotly.newPlot(                        "906c580a-8ab2-4617-b588-b02e3bce17f3",                        [{"hovertemplate":"\u003cb\u003e%{hovertext}\u003c\u002fb\u003e\u003cbr\u003e\u003cbr\u003ecolor=1\u003cbr\u003eGlucose=%{x}\u003cbr\u003ePregnancies=%{y}\u003cbr\u003eoutcome=%{z}\u003cextra\u003e\u003c\u002fextra\u003e","hovertext":{"dtype":"f8","bdata":"0YY7iFWb7r\u002fu73OIZS34P9+RRwsC\u002fZS\u002f8f5DguqJ+T9apfWkM4rcv\u002fQNFHxv5vo\u002fDHYYKtcMzj8Sd0x8f3jUPyrvzEqnXN8\u002fobOmjGcg5T+\u002fLFutN3Dmv\u002fQNFHxv5vo\u002fHrOMY5Pq2T9apfWkM4rcv63v5nN7kuo\u002fTmm1vR8Y178q78xKp1zfP+jR05RbdPU\u002f3JWTrUcC8D+5Dru5LbfjvyrvzEqnXN8\u002f7u9ziGUt+D\u002fr4KOO4ND2P\u002f06hGn++\u002f4\u002fqNTSH5AHu7\u002fRhjuIVZvuv+KzM6FRu\u002fI\u002fxUr7oEEp6b\u002flwgOb1hf0P1ql9aQzity\u002f0YY7iFWb7r8="},"legendgroup":"1","marker":{"color":"red","opacity":0.6,"symbol":"circle"},"mode":"markers","name":"1","scene":"scene","showlegend":true,"x":{"dtype":"f8","bdata":"q1rjHV1XBECmr2dEHFP3P8yvQAzh6+8\u002fClwIOqmV\u002fD\u002fvWBqz3h3zP6JZ6fBuLwFAjlyFUKAp\u002fj9fAqbpZYHnP70CSjiYfPA\u002fUwW7qGtg+D8nWmYHZsMCQNSvuWu10ANAH1rtp5He7j8vySrPYQLMv3xakfbD2fc\u002fE10CZ5e9\u002fz\u002fUr7lrtdADQM8EPpJ0zPY\u002f9QOWjB8iAEDYBTi\u002fYvT5P5Stc+o\u002fA\u002fE\u002fPLLYtO82\u002fz\u002f4WRTgzEX2PwQSMAqsa9a\u002f9QOWjB8iAECFW4sjsgH7P3RZl8nVsfQ\u002fJ1pmB2bDAkB5XqDit+Crv66wYXEKe\u002fo\u002fBFf\u002fIMdm5T8="},"y":{"dtype":"f8","bdata":"BlgtYUwJ678C\u002fAm7ZfPVPwSqGw5Zfvg\u002fBVqog5kP0L8FWqiDmQ\u002fQvwL8Cbtl89U\u002fQ19FJvm98z\u002f2h4bdMI+nP4RqulbsvwVAAvwJu2Xz1T8FWqiDmQ\u002fQv4TCgJGMiOG\u002fI0XPYrxfA0AC\u002fAm7ZfPVP0NfRSb5vfM\u002fBVqog5kP0L9DX0Um+b3zPwSqGw5Zfvg\u002fg5MxrXJ65D\u002f2h4bdMI+nP4OTMa1yeuQ\u002fBSnefDL77T8GWC1hTAnrv\u002faHht0wj6c\u002fQ19FJvm98z8FWqiDmQ\u002fQvwUp3nwy++0\u002fBlgtYUwJ67\u002fDH+RujP8AQAZYLWFMCeu\u002f9oeG3TCPpz8="},"z":{"dtype":"i1","bdata":"AQEBAQEBAQEAAQEBAQEBAQEBAAEAAQABAQEBAAEBAQ=="},"type":"scatter3d"},{"hovertemplate":"\u003cb\u003e%{hovertext}\u003c\u002fb\u003e\u003cbr\u003e\u003cbr\u003ecolor=0\u003cbr\u003eGlucose=%{x}\u003cbr\u003ePregnancies=%{y}\u003cbr\u003eoutcome=%{z}\u003cextra\u003e\u003c\u002fextra\u003e","hovertext":{"dtype":"f8","bdata":"y2iblEvi67+\u002fLFutN3Dmv2ziad7vZ8i\u002fxUr7oEEp6b+\u002fLFutN3Dmv\u002fortG95n\u002f0\u002fACWqsUEsAEC\u002fLFutN3Dmv6fRRoBx2ec\u002fqNTSH5AHu79r0u29L6rwvwlSGp\u002fQQQRAQi111gum0b9r0u29L6rwv78sW603cOa\u002f36Rjp8xe8T\u002fRhjuIVZvuv2vS7b0vqvC\u002fs\u002fAaxiP+4L\u002fFSvugQSnpv0ItddYLptG\u002f7u9ziGUt+D9r0u29L6rwv7PwGsYj\u002fuC\u002fWqX1pDOK3L\u002fFSvugQSnpv6fRRoBx2ec\u002fa9LtvS+q8L+\u002fLFutN3Dmv7kOu7ktt+O\u002fy2iblEvi679r0u29L6rwv6jU0h+QB7u\u002fa9LtvS+q8L9r0u29L6rwv1ql9aQzity\u002fuQ67uS2347+z8BrGI\u002f7gvwx2GCrXDM4\u002f0YY7iFWb7r8q78xKp1zfP78sW603cOa\u002f0YY7iFWb7r9s4mne72fIv8tom5RL4uu\u002fQi111gum0b9CLXXWC6bRv2vS7b0vqvC\u002fvyxbrTdw5r+blQaZXWfiP6fRRoBx2ec\u002fHrOMY5Pq2T9r0u29L6rwvxJ3THx\u002feNQ\u002fvyxbrTdw5r9CLXXWC6bRv+KzM6FRu\u002fI\u002fuAsvGg+JsD9CLXXWC6bRv6fRRoBx2ec\u002fxUr7oEEp6b+z8BrGI\u002f7gv2vS7b0vqvC\u002fWqX1pDOK3L9OabW9HxjXv9GGO4hVm+6\u002f35FHCwL9lL9r0u29L6rwv0ItddYLptG\u002fs\u002fAaxiP+4L+\u002fLFutN3Dmv9GGO4hVm+6\u002f0YY7iFWb7r+o1NIfkAe7v7PwGsYj\u002fuC\u002f36Rjp8xe8T+z8BrGI\u002f7gv2vS7b0vqvC\u002fQi111gum0b+\u002fLFutN3Dmv8VK+6BBKem\u002f35FHCwL9lL9r0u29L6rwv9GGO4hVm+6\u002fQi111gum0b\u002fRhjuIVZvuvwx2GCrXDM4\u002fobOmjGcg5T\u002ffkUcLAv2Uv9GGO4hVm+6\u002fy2iblEvi678es4xjk+rZPwxh6phVngVAWqX1pDOK3L+ISjIijpMDQGvS ...
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.1.1.min.js" integrity="sha256-HUEFyfiTnZJxCxur99FjbKYTvKSzwDaD3/x5TqHpFu4=" crossorigin="anonymous"></script>                <div id="34be2d2f-d257-41f0-9c05-e714e5ad081f" class="plotly-graph-div" style="height:700px; width:100%;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("34be2d2f-d257-41f0-9c05-e714e5ad081f")) {                    Plotly.newPlot(                        "34be2d2f-d257-41f0-9c05-e714e5ad081f",                        [{"hovertemplate":"\u003cb\u003e%{hovertext}\u003c\u002fb\u003e\u003cbr\u003e\u003cbr\u003ecolor=1\u003cbr\u003eGlucose=%{x}\u003cbr\u003eBMI=%{y}\u003cbr\u003eoutcome=%{z}\u003cextra\u003e\u003c\u002fextra\u003e","hovertext":{"dtype":"f8","bdata":"0YY7iFWb7r\u002fu73OIZS34P9+RRwsC\u002fZS\u002f8f5DguqJ+T9apfWkM4rcv\u002fQNFHxv5vo\u002fDHYYKtcMzj8Sd0x8f3jUPyrvzEqnXN8\u002fobOmjGcg5T+\u002fLFutN3Dmv\u002fQNFHxv5vo\u002fHrOMY5Pq2T9apfWkM4rcv63v5nN7kuo\u002fTmm1vR8Y178q78xKp1zfP+jR05RbdPU\u002f3JWTrUcC8D+5Dru5LbfjvyrvzEqnXN8\u002f7u9ziGUt+D\u002fr4KOO4ND2P\u002f06hGn++\u002f4\u002fqNTSH5AHu7\u002fRhjuIVZvuv+KzM6FRu\u002fI\u002fxUr7oEEp6b\u002flwgOb1hf0P1ql9aQzity\u002f0YY7iFWb7r8="},"legendgroup":"1","marker":{"color":"red","opacity":0.6,"symbol":"circle"},"mode":"markers","name":"1","scene":"scene","showlegend":true,"x":{"dtype":"f8","bdata":"q1rjHV1XBECmr2dEHFP3P8yvQAzh6+8\u002fClwIOqmV\u002fD\u002fvWBqz3h3zP6JZ6fBuLwFAjlyFUKAp\u002fj9fAqbpZYHnP70CSjiYfPA\u002fUwW7qGtg+D8nWmYHZsMCQNSvuWu10ANAH1rtp5He7j8vySrPYQLMv3xakfbD2fc\u002fE10CZ5e9\u002fz\u002fUr7lrtdADQM8EPpJ0zPY\u002f9QOWjB8iAEDYBTi\u002fYvT5P5Stc+o\u002fA\u002fE\u002fPLLYtO82\u002fz\u002f4WRTgzEX2PwQSMAqsa9a\u002f9QOWjB8iAECFW4sjsgH7P3RZl8nVsfQ\u002fJ1pmB2bDAkB5XqDit+Crv66wYXEKe\u002fo\u002fBFf\u002fIMdm5T8="},"y":{"dtype":"f8","bdata":"8I6TAWRR+D8EIu9ZyQHvv+S77\u002fNMO9A\u002fYe\u002f40Ipkvz8IuydJ7fK\u002fv0aEElWz8vk\u002fSN\u002fp+N4Soj+TyFigmSTsP0lEqco69vI\u002fH5pLQyN9sD8sketBisDWP20ZsYPSO9K\u002fRcQ5NZ7B9T8fMnnnes0HQJYIgICE8+c\u002fbRmxg9I70r9ct4Edjoruv8bui\u002fxIKtO\u002f8K4WB3Zt8z9GhBJVs\u002fL5P2gZ8y1gad2\u002fP\u002fM7fZUI4D95icC\u002fkoapP0HzXFJcn+U\u002fVUZPIElT9b\u002fgO8IIPjTeP8bui\u002fxIKtO\u002fXLeBHY6K7r\u002fvTktMsuv2P0UEgupPJ\u002fc\u002fmlntzSnh+j8="},"z":{"dtype":"i1","bdata":"AQEBAQEBAQEAAQEBAQEBAQEBAAEAAQABAQEBAAEBAQ=="},"type":"scatter3d"},{"hovertemplate":"\u003cb\u003e%{hovertext}\u003c\u002fb\u003e\u003cbr\u003e\u003cbr\u003ecolor=0\u003cbr\u003eGlucose=%{x}\u003cbr\u003eBMI=%{y}\u003cbr\u003eoutcome=%{z}\u003cextra\u003e\u003c\u002fextra\u003e","hovertext":{"dtype":"f8","bdata":"y2iblEvi67+\u002fLFutN3Dmv2ziad7vZ8i\u002fxUr7oEEp6b+\u002fLFutN3Dmv\u002fortG95n\u002f0\u002fACWqsUEsAEC\u002fLFutN3Dmv6fRRoBx2ec\u002fqNTSH5AHu79r0u29L6rwvwlSGp\u002fQQQRAQi111gum0b9r0u29L6rwv78sW603cOa\u002f36Rjp8xe8T\u002fRhjuIVZvuv2vS7b0vqvC\u002fs\u002fAaxiP+4L\u002fFSvugQSnpv0ItddYLptG\u002f7u9ziGUt+D9r0u29L6rwv7PwGsYj\u002fuC\u002fWqX1pDOK3L\u002fFSvugQSnpv6fRRoBx2ec\u002fa9LtvS+q8L+\u002fLFutN3Dmv7kOu7ktt+O\u002fy2iblEvi679r0u29L6rwv6jU0h+QB7u\u002fa9LtvS+q8L9r0u29L6rwv1ql9aQzity\u002fuQ67uS2347+z8BrGI\u002f7gvwx2GCrXDM4\u002f0YY7iFWb7r8q78xKp1zfP78sW603cOa\u002f0YY7iFWb7r9s4mne72fIv8tom5RL4uu\u002fQi111gum0b9CLXXWC6bRv2vS7b0vqvC\u002fvyxbrTdw5r+blQaZXWfiP6fRRoBx2ec\u002fHrOMY5Pq2T9r0u29L6rwvxJ3THx\u002feNQ\u002fvyxbrTdw5r9CLXXWC6bRv+KzM6FRu\u002fI\u002fuAsvGg+JsD9CLXXWC6bRv6fRRoBx2ec\u002fxUr7oEEp6b+z8BrGI\u002f7gv2vS7b0vqvC\u002fWqX1pDOK3L9OabW9HxjXv9GGO4hVm+6\u002f35FHCwL9lL9r0u29L6rwv0ItddYLptG\u002fs\u002fAaxiP+4L+\u002fLFutN3Dmv9GGO4hVm+6\u002f0YY7iFWb7r+o1NIfkAe7v7PwGsYj\u002fuC\u002f36Rjp8xe8T+z8BrGI\u002f7gv2vS7b0vqvC\u002fQi111gum0b+\u002fLFutN3Dmv8VK+6BBKem\u002f35FHCwL9lL9r0u29L6rwv9GGO4hVm+6\u002fQi111gum0b\u002fRhjuIVZvuvwx2GCrXDM4\u002fobOmjGcg5T\u002ffkUcLAv2Uv9GGO4hVm+6\u002fy2iblEvi678es4xjk+rZPwxh6phVngVAWqX1pDOK3L+ISjIijpMD ...

# %% [markdown]
# As can be seen in the above 3D scatter and confusion matrix, the model does not perform as well as class one in class zero.

# %% [markdown]
# #### THE END

# %% [markdown]
# Thanks for your attention :)
